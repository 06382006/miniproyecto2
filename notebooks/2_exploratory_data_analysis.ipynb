# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('../data/interim/data_for_eda.csv')

# %% [markdown]
# # Eliminamos variables no utiles

# %%
dataset.drop(['ID'], axis=1, inplace=True)
dataset.head()
# Out:
#    Default  Prct_uso_tc  Edad  Nro_prestao_retrasados  Prct_deuda_vs_ingresos  \
# 0        1     0.766127    45                       2                0.802982
# 1        0     0.957151    40                       0                0.121876
# 2        0     0.658180    38                       1                0.085113
# 3        0     0.233810    30                       0                0.036050
# 4        0     0.907239    49                       1                0.024926
#
#    Mto_ingreso_mensual  Nro_prod_financieros_deuda  Nro_retraso_60dias  \
# 0               9120.0                          13                   0
# 1               2600.0                           4                   0
# 2               3042.0                           2                   1
# 3               3300.0                           5                   0
# 4              63588.0                           7                   0
#
#    Nro_creditos_hipotecarios  Nro_retraso_ultm3anios  Nro_dependiente
# 0                          6                       0              2.0
# 1                          0                       0              1.0
# 2                          0                       0              0.0
# 3                          0                       0              0.0
# 4                          1                       0              0.0

# %%
dataset.describe()
# Out:
#              Default    Prct_uso_tc           Edad  Nro_prestao_retrasados  \
# count  105000.000000  105000.000000  105000.000000           105000.000000
# mean        0.066724       6.073045      52.261133                0.422657
# std         0.249544     257.857170      14.768872                4.221403
# min         0.000000       0.000000       0.000000                0.000000
# 25%         0.000000       0.030007      41.000000                0.000000
# 50%         0.000000       0.155936      52.000000                0.000000
# 75%         0.000000       0.561892      63.000000                0.000000
# max         1.000000   50708.000000     107.000000               98.000000
#
#        Prct_deuda_vs_ingresos  Mto_ingreso_mensual  \
# count           105000.000000         8.422700e+04
# mean               354.648275         6.636707e+03
# std               2104.697362         1.359485e+04
# min                  0.000000         0.000000e+00
# 25%                  0.175069         3.400000e+03
# 50%                  0.366178         5.400000e+03
# 75%                  0.866588         8.228000e+03
# max             329664.000000         3.008750e+06
#
#        Nro_prod_financieros_deuda  Nro_retraso_60dias  \
# count               105000.000000       105000.000000
# mean                     8.442286            0.268381
# std                      5.136229            4.197708
# min                      0.000000            0.000000
# 25%                      5.000000            0.000000
# 50%                      8.000000            0.000000
# 75%                     11.000000            0.000000
# max                     58.000000           98.000000
#
#        Nro_creditos_hipotecarios  Nro_retraso_ultm3anios  Nro_dependiente
# count              105000.000000           105000.000000    102240.000000
# mean                    1.018705                0.242181         0.757942
# std                     1.134358                4.184350         1.116190
# min                     0.000000                0.000000         0.000000
# 25%                     0.000000                0.000000         0.000000
# 50%                     1.000000                0.000000         0.000000
# 75%                     2.000000                0.000000         1.000000
# max                    54.000000               98.000000        20.000000

# %%
for col in dataset.columns:
    plt.figure(figsize=(7,4))

    plt.title(col)
    sns.boxplot(x=dataset['Default'],y=dataset[col])
    plt.show()

# %%
dataset.to_csv('../data/interim/data_for_features.csv', index=False)
